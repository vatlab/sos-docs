# %% [markdown]
# # Examples used in Wang and Peng 2018

# %% [markdown]
# This vignette demonstrates how examples in the SoS manuscript (Wang G. and Peng B. 2018) are reproduced.

# %% [markdown]
# ## Requirement
#
# To run the examples, SoS workflow system have to be installed. See [here](https://vatlab.github.io/sos-docs/#runningsos) for an instruction. The interactive analysis part of the RNA-seq differential expression example additionally requires one to have a Jupyter environment (Jupyter Lab or Jupyter Notebook) installed, with R kernel. Although some examples are written in `*.ipynb` the Jupyter format, there is no need to install notebook related software to execute those notebooks from command line (as will be shown below).
#
# If you edit plain `*.sos` file with `vim` editor you should see customized syntax highlighting being applied to `*.sos` script. To use SoS Notebook as IDE to edit examples in `*.ipynb` format, the SoS Notebook package has to be installed. Notice that the SoS workflow system only uses SoS Notebook as the IDE and does not rely on its cross-language data communication features. So there is no need to configure SoS Notebook for different kernels if your goal is to edit and run SoS workflow system.

# %% [markdown]
# ## Large scale regression examples

# %% [markdown]
# These examples are written in plain text format SoS script. Here is a screen-shot from `vim` editor:

# %%
%preview Regression.png
# Out:
# > Regression.png (115.2 KiB):

# %% [markdown]
# ### "Process oriented" style example

# %%
sos run Process_Oriented.sos -p Process_Oriented_Report.html -d
# Out:
# INFO: output:   data_1.train.csv, data_1.test.csv, ... (10 items)
# INFO: output:   data_1.ridge.predicted.csv, data_1.ridge.coef.csv, ... (10 items)
# INFO: output:   data_1.ridge.mse.csv, data_2.ridge.mse.csv, ... (5 items)
# INFO: Workflow ridge (ID=6a3ee845eb416572) is executed successfully with 3 completed steps and 15 completed substeps.
# INFO: Workflow DAG saved to Process_Oriented_061318_1727.dot
# INFO: lasso_1 (index=0) is ignored due to saved signature
# INFO: lasso_1 (index=1) is ignored due to saved signature
# INFO: lasso_1 (index=2) is ignored due to saved signature
# INFO: lasso_1 (index=3) is ignored due to saved signature
# INFO: lasso_1 (index=4) is ignored due to saved signature
# INFO: output:   data_1.train.csv, data_1.test.csv, ... (10 items)
# INFO: output:   data_1.lasso.predicted.csv, data_1.lasso.coef.csv, ... (10 items)
# INFO: output:   data_1.lasso.mse.csv, data_2.lasso.mse.csv, ... (5 items)
# INFO: Workflow lasso (ID=b3ef83b059020324) is executed successfully with 2 completed steps, 10 completed substeps, 1 ignored step and 5 ignored substeps.
# INFO: Workflow DAG saved to Process_Oriented_061318_1727.dot
# INFO: output:   []
# pandoc.css
# pandoc.css:   0%|                                      | 0/4203 [00:00<?, ?it/s]
# INFO: Report saved to report.html
# INFO: output:   []
# INFO: Workflow default (ID=d107c1ed414121b3) is executed successfully with 7 completed steps, 27 completed substeps, 1 ignored step and 5 ignored substeps.
# INFO: Workflow DAG saved to Process_Oriented_061318_1727.dot
# INFO: Summary of workflow saved to Process_Oriented_Report.html

# %% [markdown]
# The outcome of this workflow is a table of performance comparison, summarized in `report.html`. Here is the content of it:

# %%
%preview report.html
# Out:
# > report.html (597 B):
# Method Avg. Estimation Error Avg. Prediction Error LASSO [1.281750125] [14.58175988787038] Ridge [0.41762759535508404] [2.9796641600812976]

# %% [markdown]
# Also available, due to `-p` and `-d` options, is a workflow status report automatically generated by the workflow. See here for the [status report](Process_Oriented_Report.html).
