# %% [markdown]
# # How to group many small tasks into larger ones

# %% [markdown]
# * **Difficulty level**: intermediate
# * **Time need to lean**: 10 minutes or less
# * **Key points**:
#   * Option `trunk_size` groups small tasks into larger ones
#   * Option `trunk_workers` determines number of workers per master task
#   * Tasks can be dispatched and executed on multiple nodes on a cluster system

# %% [markdown]
# ## The problem with many small tasks

# %% [markdown]
# From time to time you may face the problem with many small tasks, such as running millions of simulations or analyzing thousands of genes. Whereas each simulation or analysis takes just a few minutes to complete, the entire analysis will take a long time and needs to be performed on a cluster. However, most cluster systems does not welcome millions or small tasks as managing a large number of jobs can pose management challenges to the scheduler.

# %% [markdown]
# ## The bash script approach

# %% [markdown]
# What users have usually done are running these analysis in batch, which works more or less like the following script if implemented in SoS:

# %%
input: for_each=dict(batch=range(4))

bash: args=f'{{filename}} {batch*4+1} {(batch+1)*4}'
   for id in `seq $1 $2`
   do
      echo "Processing $id"
   done
# Out:
# Processing 1
# Processing 2
# Processing 3
# Processing 4
# Processing 5
# Processing 6
# Processing 7
# Processing 8
# Processing 9
# Processing 10
# Processing 11
# Processing 12
# Processing 13
# Processing 14
# Processing 15
# Processing 16

# %% [markdown]
# The `args` option here determines what will be passed to the underlying `bash` command, which should contain `{filename}` as the filename of the temporary file generated by SoS. In this particular example we use
#
# ```
# f'{{filename}} {batch*4+1} {(batch+1)*4}'
# ```
# so that the following bash commands will be executed
# ```
# bash {filename} 1 4
# bash {filename} 5 8
# bash {filename} 9 12
# bash {filename} 13 16
# ```
# for substeps with `batch` equals to `0`, `1`, `2` and `3` respectively.

# %% [markdown]
# Now that we have fewer number of jobs, we can submit the shell scripts to a batch system as tasks

# %%
input: for_each=dict(batch=range(4))

task: queue='localhost'
bash: args=f'{{filename}} {batch*4+1} {(batch+1)*4}'
   for id in `seq $1 $2`
   do
      echo "Processing $id"
   done
# Out:
# <table id="task_macpro_ff4f01b569a342c0_5b049a7d9c454c65846133906de5036f" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_ff4f01b569a342c0_5b049a7d9c454c65846133906de5036f" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>ff4f01b569a342c0<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'ff4f01b569a342c0', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'ff4f01b569a342c0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'ff4f01b569a342c0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'ff4f01b569a342c0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_ff4f01b569a342c0_5b049a7d9c454c65846133906de5036f"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_e4a60f6d38807dc2">e4a60f6d38807dc2<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_scratch_0">scratch_0<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'scratch_0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_ff4f01b569a342c0_5b049a7d9c454c65846133906de5036f" class="completed" datetime="1566439395578.016">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_ff4f01b569a342c0_5b049a7d9c454c65846133906de5036f">completed</span></pre>
#     </td>
# </tr>
# </table>
# <table id="task_macpro_a6a7b9b568712239_5b049a7d9c454c65846133906de5036f" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_a6a7b9b568712239_5b049a7d9c454c65846133906de5036f" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>a6a7b9b568712239<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'a6a7b9b568712239', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'a6a7b9b568712239', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'a6a7b9b568712239', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'a6a7b9b568712239', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_a6a7b9b568712239_5b049a7d9c454c65846133906de5036f"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_e4a60f6d38807dc2">e4a60f6d38807dc2<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_scratch_0">scratch_0<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'scratch_0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_a6a7b9b568712239_5b049a7d9c454c65846133906de5036f" class="completed" datetime="1566439395604.384">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_a6a7b9b568712239_5b049a7d9c454c65846133906de5036f">completed</span></pre>
#     </td>
# </tr>
# </table>
# <table id="task_macpro_bb6857c63e9e1da2_5b049a7d9c454c65846133906de5036f" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_bb6857c63e9e1da2_5b049a7d9c454c65846133906de5036f" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>bb6857c63e9e1da2<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'bb6857c63e9e1da2', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'bb6857c63e9e1da2', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'bb6857c63e9e1da2', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'bb6857c63e9e1da2', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_bb6857c63e9e1da2_5b049a7d9c454c65846133906de5036f"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_e4a60f6d38807dc2">e4a60f6d38807dc2<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_scratch_0">scratch_0<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'scratch_0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_bb6857c63e9e1da2_5b049a7d9c454c65846133906de5036f" class="completed" datetime="1566439395689.1938">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_bb6857c63e9e1da2_5b049a7d9c454c65846133906de5036f">completed</span></pre>
#     </td>
# </tr>
# </table>
# <table id="task_macpro_7d66fa8d1d3af308_5b049a7d9c454c65846133906de5036f" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_7d66fa8d1d3af308_5b049a7d9c454c65846133906de5036f" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>7d66fa8d1d3af308<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'7d66fa8d1d3af308', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'7d66fa8d1d3af308', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'7d66fa8d1d3af308', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'7d66fa8d1d3af308', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_7d66fa8d1d3af308_5b049a7d9c454c65846133906de5036f"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_e4a60f6d38807dc2">e4a60f6d38807dc2<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'e4a60f6d38807dc2', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_scratch_0">scratch_0<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'scratch_0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_7d66fa8d1d3af308_5b049a7d9c454c65846133906de5036f" class="completed" datetime="1566439395643.6108">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_7d66fa8d1d3af308_5b049a7d9c454c65846133906de5036f">completed</span></pre>
#     </td>
# </tr>
# </table>

# %% [markdown]
# The tasks in this example are executed locally but you can send the tasks to a remote host using
#
# ```
# task: queue='host'
# ```
# or
# ```
# %run -q host
# ```

# %% [markdown]
# ## Grouping SoS tasks

# %% [markdown]
# <div class="bs-callout bs-callout-primary" role="alert">
#   <h4>The <code>trunk_size</code> task option</h4>
#   <p>The <code>trunk_size=n</code> option groups tasks into groups of size `n` before submitting them to an executor. As a special case, if option `trunk_size` is specified but with a value `None`, all tasks from the step will be grouped together.
# </div>

# %% [markdown]
# The aforementioned example can be implemented in a much easier way as follows using the `trunk_size` task option:

# %%
input: for_each=dict(id=range(16))

task: trunk_size=4, queue='localhost'
bash: expand=True
    echo "Processing {id+1}"
# Out:
# <table id="task_macpro_M4_b1c14581f8718798_89e55a4876bf4d6e93802e8d5b686724" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_M4_b1c14581f8718798_89e55a4876bf4d6e93802e8d5b686724" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>M4_b1c14581f8718798<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'M4_b1c14581f8718798', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'M4_b1c14581f8718798', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'M4_b1c14581f8718798', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'M4_b1c14581f8718798', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_M4_b1c14581f8718798_89e55a4876bf4d6e93802e8d5b686724"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_b88e72a973ed771e">b88e72a973ed771e<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'b88e72a973ed771e', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_default">default<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'default', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_M4_b1c14581f8718798_89e55a4876bf4d6e93802e8d5b686724" class="completed" datetime="1566439403140.5261">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_M4_b1c14581f8718798_89e55a4876bf4d6e93802e8d5b686724">completed</span></pre>
#     </td>
# </tr>
# </table>
# <table id="task_macpro_M4_314e3b190349e610_89e55a4876bf4d6e93802e8d5b686724" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_M4_314e3b190349e610_89e55a4876bf4d6e93802e8d5b686724" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>M4_314e3b190349e610<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'M4_314e3b190349e610', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'M4_314e3b190349e610', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'M4_314e3b190349e610', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'M4_314e3b190349e610', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_M4_314e3b190349e610_89e55a4876bf4d6e93802e8d5b686724"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_b88e72a973ed771e">b88e72a973ed771e<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'b88e72a973ed771e', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_default">default<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'default', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_M4_314e3b190349e610_89e55a4876bf4d6e93802e8d5b686724" class="completed" datetime="1566439403176.718">Ran for 2 sec</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_M4_314e3b190349e610_89e55a4876bf4d6e93802e8d5b686724">completed</span></pre>
#     </td>
# </tr>
# </table>
# <table id="task_macpro_M4_da141df4fcd05ff0_89e55a4876bf4d6e93802e8d5b686724" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_M4_da141df4fcd05ff0_89e55a4876bf4d6e93802e8d5b686724" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>M4_da141df4fcd05ff0<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'M4_da141df4fcd05ff0', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'M4_da141df4fcd05ff0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'M4_da141df4fcd05ff0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'M4_da141df4fcd05ff0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_M4_da141df4fcd05ff0_89e55a4876bf4d6e93802e8d5b686724"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_b88e72a973ed771e">b88e72a973ed771e<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'b88e72a973ed771e', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_default">default<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'default', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_M4_da141df4fcd05ff0_89e55a4876bf4d6e93802e8d5b686724" class="completed" datetime="1566439403211.519">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_M4_da141df4fcd05ff0_89e55a4876bf4d6e93802e8d5b686724">completed</span></pre>
#     </td>
# </tr>
# </table>
# <table id="task_macpro_M4_0383606282732b4f_89e55a4876bf4d6e93802e8d5b686724" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_M4_0383606282732b4f_89e55a4876bf4d6e93802e8d5b686724" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>M4_0383606282732b4f<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'M4_0383606282732b4f', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'M4_0383606282732b4f', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'M4_0383606282732b4f', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'M4_0383606282732b4f', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_M4_0383606282732b4f_89e55a4876bf4d6e93802e8d5b686724"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_b88e72a973ed771e">b88e72a973ed771e<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'b88e72a973ed771e', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'b88e72a973ed771e', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_default">default<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'default', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'default', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_M4_0383606282732b4f_89e55a4876bf4d6e93802e8d5b686724" class="completed" datetime="1566439404858.155">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_M4_0383606282732b4f_89e55a4876bf4d6e93802e8d5b686724">completed</span></pre>
#     </td>
# </tr>
# </table>

# %% [markdown]
# In this example, 15 tasks are generated from 15 substeps, each running a bash script
# ```
# echo "Processing {id}"
# ```
# with `id` = `0`, ..., `15` respectively.
#
# With option `trunk_size=4`, the tasks are grouped into master tasks with names starting with `M5_`.

# %% [markdown]
# ## Executing subtasks in parallel

# %% [markdown]
# <div class="bs-callout bs-callout-primary" role="alert">
#   <h4>The <code>trunk_workers</code> task option</h4>
#   <p>The <code>trunk_workers=n</code> option specify the number of concurrent workers in each task. Similar to option <code>-j</code> for commands <code>sos run</code> and <code>sos execute</code>, it accepts the specification of multiple worker processes on multiple nodes. The value of this parameter will affects variables such as <code>nodes</code>, <code>cores</code>, <code>walltime</code> and <code>mem</code> in task templates.
# </div>

# %% [markdown]
# The master tasks by default execute subtasks sequentially. If the master task has a large number of subtasks and there are computing resources available, you can specifying another option `trunk_workers` to set the number of workers for each master task. For example, in the following SoS workflow, the 16 tasks are submitted as a single (master) task and will be processed by two workers.

# %%
input: for_each=dict(id=range(16))

task: trunk_size=None, trunk_workers=2, queue='localhost'
bash: expand=True
    echo "Processing {id+1}"
# Out:
# <table id="task_macpro_M16_c0eee456c0ccde11_6ed40373ed5f4ff6805798cc9c4b842c" class="task_table completed">
# <tr>
#     <td class="task_icon">
#       <i id="task_status_icon_macpro_M16_c0eee456c0ccde11_6ed40373ed5f4ff6805798cc9c4b842c" class="fa fa-2x fa-fw fa-check-square-o"</i>
#     </td>
#     <td class="task_id">
#       <span><pre><i class="fa fa-fw fa-sitemap"></i></pre><pre>M16_c0eee456c0ccde11<div class="task_id_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', task:'M16_c0eee456c0ccde11', queue: 'macpro'})"></i><i class="fa fa-fw fa-play" onclick="task_action({action:'execute', task:'M16_c0eee456c0ccde11', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', task:'M16_c0eee456c0ccde11', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', task:'M16_c0eee456c0ccde11', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_tags">
#       <span id="status_tags_macpro_M16_c0eee456c0ccde11_6ed40373ed5f4ff6805798cc9c4b842c"><pre><i class="fa fa-fw fa-info-circle"></i></pre><pre class="task_tags task_tag_7a97a00258a58e5d">7a97a00258a58e5d<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'7a97a00258a58e5d', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'7a97a00258a58e5d', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'7a97a00258a58e5d', queue: 'macpro'})"></i></div></pre><pre class="task_tags task_tag_scratch_0">scratch_0<div class="task_tag_actions"><i class="fa fa-fw fa-refresh" onclick="task_action({action:'status', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-stop"" onclick="task_action({action:'kill', tag:'scratch_0', queue: 'macpro'})"></i><i class="fa fa-fw fa-trash"" onclick="task_action({action:'purge', tag:'scratch_0', queue: 'macpro'})"></i></div></pre></span>
#     </td>
#     <td class="task_timer">
#       <pre><i class="fa fa-fw fa-clock-o"></i><time id="status_duration_macpro_M16_c0eee456c0ccde11_6ed40373ed5f4ff6805798cc9c4b842c" class="completed" datetime="1566439411317.599">Ran for < 5 seconds</time></pre>
#     </td>
#     <td class="task_status">
#       <pre><i class="fa fa-fw fa-tasks"></i><span id="status_text_macpro_M16_c0eee456c0ccde11_6ed40373ed5f4ff6805798cc9c4b842c">completed</span></pre>
#     </td>
# </tr>
# </table>

# %% [markdown]
# ## Executing subtasks on cluster system

# %% [markdown]
# When you submit a master task to the cluster system, you typically need to specify the resources needed for tasks, using options `walltime`, `mem` and `cores`. These variables will be translated and expanded in a task template (defined in SoS configuration files).
#
# For example, with the following template for a SLURM-based cluster system,

# %% [markdown]
# ```sh
# #!/bin/bash
# #SBATCH --time={walltime}
# #SBATCH --nodes={nodes}
# #SBATCH --ntasks-per-node={cores}
# #SBATCH --mem-per-cpu={mem // cores // 1000000000}G
# #SBATCH --job-name={task}
# #SBATCH --output=/home/{user_name}/.sos/{task}.out
# #SBATCH --error=/home/{user_name}/.sos/{task}.err
#
# sos execute {task} -v {verbosity} -s {sig_mode} -r {run_mode}
# ```

# %% [markdown]
# A task with options `mem='1G'` and `walltime='12h'` will populate the template with variables `mem=1000000000` (1G) and `walltime=`01:00:00`.

# %%
%run
task: mem='1G', walltime='1h'
bash:
    echo "Processing data"
# Out:
# Processing data

# %% [markdown]
# If you group multiple tasks using options `trunk_size` and `trunk_worker`, the template variables will be adjusted automatically. For example,

# %% [markdown]
# ```python
# input: for_each=dict(id=range(16))
#
# task: trunk_size=None, trunk_workers=2, mem='1G', walltime='1h'
# bash: expand=True
#     echo "Processing {id+1}"
# ```

# %% [markdown]
# will generate `mem='2000000000' (2G) and `walltime=08:00:00' because two concurrent workers will use double the RAM, and each worker will process 8 tasks sequentially, in a total of 8 hours.

# %% [markdown]
# ## Executing subtasks on multiple computing nodes of a cluster system

# %% [markdown]
# If you have many small tasks and would like to submit them as a small number or a single job on the cluster system, and would like to make use of multiple nodes to process them, you can specify more than one computing nodes with option `trunk_workers`. In this case, `trunk_workers` should be a list with its length indicating the number of nodes and its elements indicating the number of workers on each node.
#
# For example, with the template above, running `sos run test.sos -q slurm_cluster` will create a single master task with 16 subtasks, processed by 8 workers on two computing nodes.

# %% [markdown]
# ```python
# input: for_each=dict(id=range(16))
#
# task: trunk_size=None, trunk_workers=[4, 4], mem='1G', walltime='1h'
# bash: expand=True
#     echo "Processing {id+1}"
# ```

# %% [markdown]
# Under the hood, sos will
#
# 1. determine number of nodes and set variable `nodes` to `2`
# 2. adjust `mem` and `walltime` according to number of concurrent and sequential tasks.
# 3. populate the task template with variables `nodes`, `mem`, `walltime` etc
# 4. submit the generated shell script to create a multi-node job
# 5. Because the task is executed on a cluster system, it will automatically recognize the nodes and processes per node, create workers accordingly to process the tasks on multiple nodes.

# %% [markdown]
# ## Further reading
#
# * [Running workflows on a cluster system](cluster.html) for how to execute an entire workflow on a cluster system.
